# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

data=pd.read_csv("../input/corona-virus-report/covid_19_clean_complete.csv")

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long     Date  Confirmed  Deaths  \
# 0            NaN    Afghanistan  33.0000  65.0000  1/22/20          0       0
# 1            NaN        Albania  41.1533  20.1683  1/22/20          0       0
# 2            NaN        Algeria  28.0339   1.6596  1/22/20          0       0
# 3            NaN        Andorra  42.5063   1.5218  1/22/20          0       0
# 4            NaN         Angola -11.2027  17.8739  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data.tail(10)
# Out:
#                  Province/State         Country/Region        Lat        Long  \
# 17126                       NaN                   Mali  17.570692   -3.996166
# 17127                       NaN  Saint Kitts and Nevis  17.357822  -62.782998
# 17128     Northwest Territories                 Canada  64.825500 -124.845700
# 17129                     Yukon                 Canada  64.282300 -135.000000
# 17130                       NaN                 Kosovo  42.602636   20.902977
# 17131                       NaN                  Burma  21.916200   95.956000
# 17132                  Anguilla         United Kingdom  18.220600  -63.068600
# 17133    British Virgin Islands         United Kingdom  18.420700  -64.640000
# 17134  Turks and Caicos Islands         United Kingdom  21.694000  -71.797900
# 17135                       NaN             MS Zaandam   0.000000    0.000000
#
#           Date  Confirmed  Deaths  Recovered
# 17126  3/29/20         18       1          0
# ...

# %%
data.shape
# Out:
# (17136, 8)

# %%
data.describe()
# Out:
#                 Lat          Long      Confirmed        Deaths     Recovered
# count  17136.000000  17136.000000   17136.000000  17136.000000  17136.000000
# mean      22.238772     23.356497     523.227766     20.676237    160.086018
# std       24.364494     71.494642    4798.964492    267.670675   2252.351806
# min      -41.454500   -135.000000       0.000000      0.000000      0.000000
# 25%        8.599125    -20.026050       0.000000      0.000000      0.000000
# 50%       23.914900     20.921188       0.000000      0.000000      0.000000
# 75%       41.316075     85.953175      28.000000      0.000000      1.000000
# max       71.706900    178.065000  140886.000000  10779.000000  62570.000000

# %%
data.boxplot()

# %%
data.rename({'Country/Region':'Country'},axis=1,inplace=True)

# %%
data.head()
# Out:
#   Province/State      Country      Lat     Long     Date  Confirmed  Deaths  \
# 0            NaN  Afghanistan  33.0000  65.0000  1/22/20          0       0
# 1            NaN      Albania  41.1533  20.1683  1/22/20          0       0
# 2            NaN      Algeria  28.0339   1.6596  1/22/20          0       0
# 3            NaN      Andorra  42.5063   1.5218  1/22/20          0       0
# 4            NaN       Angola -11.2027  17.8739  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data['Country'].value_counts().sort_values()
# Out:
# Malaysia            68
# Timor-Leste         68
# Kazakhstan          68
# Mauritius           68
# Bahrain             68
#                   ...
# Australia          544
# United Kingdom     680
# France             680
# Canada             952
# China             2244
# Name: Country, Length: 177, dtype: int64

# %%
data.plot(x='Date',y='Confirmed') #plot between date and confirmed
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*2, Size[1]*1, forward=True)

# %%
data.plot(x='Date',y='Deaths') #plot between date and no of deaths
plt.xlabel('Date', fontsize=18)
plt.ylabel('Number of deaths', fontsize=16)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*2.5, Size[1]*1.5, forward=True)

# %%
data.plot(x='Date',y='Recovered') #plot between date and recovered number
plt.xlabel('Date', fontsize=18)
plt.ylabel('Recovered', fontsize=16)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*2, Size[1]*1.5, forward=True)

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe432bd49e8>,
# ...
#       dtype=object)

# %%
data[data.Deaths>10]
# Out:
#       Province/State         Country      Lat      Long     Date  Confirmed  \
# 62             Hubei           China  30.9756  112.2707  1/22/20        444
# 314            Hubei           China  30.9756  112.2707  1/23/20        444
# 566            Hubei           China  30.9756  112.2707  1/24/20        549
# 818            Hubei           China  30.9756  112.2707  1/25/20        761
# 1070           Hubei           China  30.9756  112.2707  1/26/20       1058
# ...              ...             ...      ...       ...      ...        ...
# 17089            NaN          Sweden  63.0000   16.0000  3/29/20       3700
# 17090            NaN     Switzerland  46.8182    8.2275  3/29/20      14829
# 17097            NaN          Turkey  38.9637   35.2433  3/29/20       9217
# 17107            NaN  United Kingdom  55.3781   -3.4360  3/29/20      19522
# 17109            NaN              US  37.0902  -95.7129  3/29/20     140886
#
#        Deaths  Recovered
# 62         17         28
# ...

# %%
data.isnull().sum()
# Out:
# Province/State    11832
# Country               0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# dtype: int64

# %%
country_list=data.groupby(['Country']).max().reset_index(drop=None)
print(country_list[['Country','Confirmed','Deaths','Recovered']])
# Out:
#                 Country  Confirmed  Deaths  Recovered
# 0           Afghanistan        120       4          2
# 1               Albania        212      10         33
# 2               Algeria        511      31         65
# 3               Andorra        334       6          1
# 4                Angola          7       2          0
# ..                  ...        ...     ...        ...
# 172           Venezuela        119       2         39
# 173             Vietnam        188       0         25
# 174  West Bank and Gaza        109       1         18
# 175              Zambia         29       0          0
# 176            Zimbabwe          7       1          0
#
# [177 rows x 4 columns]

# %%
country_list=data.groupby(['Lat']).max().reset_index(drop=None)
print(country_list[['Lat','Confirmed','Deaths','Recovered']])
# Out:
#          Lat  Confirmed  Deaths  Recovered
# 0   -41.4545         66       0          5
# 1   -40.9006        514       1         56
# 2   -38.4161        745      19         72
# 3   -37.8136        769       4        191
# 4   -35.6751       2139       7         75
# ..       ...        ...     ...        ...
# 238  64.0000       1240      11         10
# 239  64.2823          4       0          0
# 240  64.8255          1       0          0
# 241  64.9631       1020       5        135
# 242  71.7069         10       0          2
#
# [243 rows x 4 columns]

# %%
country_list=data.groupby(['Long']).max().reset_index(drop=None)
print(country_list[['Long','Confirmed','Deaths','Recovered']])
# Out:
#          Long  Confirmed  Deaths  Recovered
# 0   -135.0000          4       0          0
# 1   -124.8457          1       0          0
# 2   -123.1207        884      17          0
# 3   -122.6655         13       0          0
# 4   -116.5765        621       2          0
# ..        ...        ...     ...        ...
# 241  151.2093       1791       8          4
# 242  153.4000        656       2          8
# 243  165.6180         15       0          0
# 244  174.8860        514       1         56
# 245  178.0650          5       0          0
#
# [246 rows x 4 columns]

# %%
data.plot(x='Country',y='Recovered') #plot between Country and recovered number
plt.xlabel('Country', fontsize=18)
plt.ylabel('Recovered', fontsize=16)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*3, Size[1]*1.5, forward=True)

# %%
plt.plot('Date', 'Deaths', data=data.groupby(['Date']).sum().reset_index(drop=None), color='red')
plt.plot('Date', 'Recovered', data=data.groupby(['Date']).sum().reset_index(drop=None), color='blue')
plt.xticks(rotation=60)
plt.ylabel('Number of cases',fontsize=10)
plt.xlabel('Dates',fontsize=10)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*3, Size[1]*2, forward=True) 
plt.legend()
plt.show()
