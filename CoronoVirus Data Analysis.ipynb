# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline

data=pd.read_csv("../input/corona-virus-report/covid_19_clean_complete.csv")

# %%
data.head()
# Out:
#   Province/State    Country      Lat      Long     Date  Confirmed  Deaths  \
# 0            NaN   Thailand  15.0000  101.0000  1/22/20          2       0
# 1            NaN      Japan  36.0000  138.0000  1/22/20          2       0
# 2            NaN  Singapore   1.2833  103.8333  1/22/20          0       0
# 3            NaN      Nepal  28.1667   84.2500  1/22/20          0       0
# 4            NaN   Malaysia   2.5000  112.5000  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data.tail(10)
# Out:
#       Province/State  Country/Region      Lat      Long     Date  Confirmed  \
# 16056            NaN     Gambia, The  13.4432  -15.3101  3/19/20          1
# 16057     Montserrat  United Kingdom  16.7425  -62.1874  3/19/20          1
# 16058            NaN    Bahamas, The  25.0343  -77.3963  3/19/20          3
# 16059      Greenland         Denmark  71.7069  -42.6043  3/19/20          2
# 16060  New Caledonia          France -20.9043  165.6180  3/19/20          2
# 16061        Bermuda  United Kingdom  32.3078  -64.7505  3/19/20          2
# 16062            NaN            Chad  15.4542   18.7322  3/19/20          1
# 16063            NaN     El Salvador  13.7942  -88.8965  3/19/20          1
# 16064            NaN            Fiji -17.7134  178.0650  3/19/20          1
# 16065            NaN       Nicaragua  12.8654  -85.2072  3/19/20          1
#
#        Deaths  Recovered
# 16056       0          0
# 16057       0          0
# 16058       0          0
# 16059       0          0
# 16060       0          0
# 16061       0          0
# 16062       0          0
# 16063       0          0
# 16064       0          0
# 16065       0          0

# %%
data.shape
# Out:
# (16066, 8)

# %%
data.describe()
# Out:
#                 Lat          Long     Confirmed        Deaths     Recovered
# count  16066.000000  16066.000000  16066.000000  16066.000000  16066.000000
# mean      26.374601      5.948706    266.483381      8.914291     99.965082
# std       23.041904     81.367145   3251.867180    138.068515   1719.294077
# min      -41.454500   -157.498300      0.000000      0.000000      0.000000
# 25%       13.193900    -71.563900      0.000000      0.000000      0.000000
# 50%       33.000000     11.502100      0.000000      0.000000      0.000000
# 75%       42.500000     69.345100      7.000000      0.000000      0.000000
# max       71.706900    178.065000  67800.000000   3405.000000  57682.000000

# %%
data.boxplot()

# %%
data.rename({'Country/Region':'Country'},axis=1,inplace=True)

# %%
data.head()
# Out:
#   Province/State    Country      Lat      Long     Date  Confirmed  Deaths  \
# 0            NaN   Thailand  15.0000  101.0000  1/22/20          2       0
# 1            NaN      Japan  36.0000  138.0000  1/22/20          2       0
# 2            NaN  Singapore   1.2833  103.8333  1/22/20          0       0
# 3            NaN      Nepal  28.1667   84.2500  1/22/20          0       0
# 4            NaN   Malaysia   2.5000  112.5000  1/22/20          0       0
#
#    Recovered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
data['Country'].value_counts().sort_values()
# Out:
# Sweden           58
# Albania          58
# New Zealand      58
# Portugal         58
# Malaysia         58
#                ...
# Australia       522
# France          522
# Canada          638
# China          1914
# US             3248
# Name: Country, Length: 155, dtype: int64

# %%
data.plot(x='Date',y='Confirmed') #plot between date and confirmed
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*2, Size[1]*1, forward=True)

# %%
data.plot(x='Date',y='Deaths') #plot between date and no of deaths
plt.xlabel('Date', fontsize=18)
plt.ylabel('Number of deaths', fontsize=16)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*2.5, Size[1]*1.5, forward=True)

# %%
data.plot(x='Date',y='Recovered') #plot between date and recovered number
plt.xlabel('Date', fontsize=18)
plt.ylabel('Recovered', fontsize=16)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*2, Size[1]*1.5, forward=True)

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa0295eb208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa029eb52b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa02982e208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa02949a668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa029064940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa0290073c8>]],
#       dtype=object)

# %%
data[data.Deaths>10]
# Out:
#        Province/State         Country      Lat      Long     Date  Confirmed  \
# 154             Hubei           China  30.9756  112.2707  1/22/20        444
# 431             Hubei           China  30.9756  112.2707  1/23/20        444
# 708             Hubei           China  30.9756  112.2707  1/24/20        549
# 985             Hubei           China  30.9756  112.2707  1/25/20        761
# 1262            Hubei           China  30.9756  112.2707  1/26/20       1058
# ...               ...             ...      ...       ...      ...        ...
# 15946          France          France  46.2276    2.2137  3/19/20      10871
# 15948           Henan           China  33.8820  113.6140  3/19/20       1273
# 15958    Heilongjiang           China  47.8620  127.7615  3/19/20        483
# 16001  United Kingdom  United Kingdom  55.3781   -3.4360  3/19/20       2689
# 16038     Netherlands     Netherlands  52.1326    5.2913  3/19/20       2460
#
#        Deaths  Recovered
# 154        17         28
# 431        17         28
# 708        24         31
# 985        40         32
# 1262       52         42
# ...       ...        ...
# 15946     243         12
# 15948      22       1250
# 15958      13        460
# 16001     137         65
# 16038      76          2
#
# [288 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Province/State    8468
# Country              0
# Lat                  0
# Long                 0
# Date                 0
# Confirmed            0
# Deaths               0
# Recovered            0
# dtype: int64

# %%
country_list=data.groupby(['Country']).max().reset_index(drop=None)
print(country_list[['Country','Confirmed','Deaths','Recovered']])
# Out:
#                  Country  Confirmed  Deaths  Recovered
# 0            Afghanistan         22       0          1
# 1                Albania         64       2          0
# 2                Algeria         87       9         32
# 3                Andorra         53       0          1
# 4    Antigua and Barbuda          1       0          0
# ..                   ...        ...     ...        ...
# 150              Uruguay         79       0          0
# 151           Uzbekistan         23       0          0
# 152            Venezuela         42       0          0
# 153              Vietnam         85       0         16
# 154               Zambia          2       0          0
#
# [155 rows x 4 columns]

# %%
country_list=data.groupby(['Lat']).max().reset_index(drop=None)
print(country_list[['Lat','Confirmed','Deaths','Recovered']])
# Out:
#          Lat  Confirmed  Deaths  Recovered
# 0   -41.4545         10       0          3
# 1   -40.9006         28       0          0
# 2   -38.4161         97       3          3
# 3   -37.8136        121       0          8
# 4   -35.6751        238       0          0
# ..       ...        ...     ...        ...
# 263  61.8926         72       0          0
# 264  63.0000       1439      11         16
# 265  64.0000        400       0         10
# 266  64.9631        330       5          8
# 267  71.7069          2       0          0
#
# [268 rows x 4 columns]

# %%
country_list=data.groupby(['Long']).max().reset_index(drop=None)
print(country_list[['Long','Confirmed','Deaths','Recovered']])
# Out:
#          Long  Confirmed  Deaths  Recovered
# 0   -157.4983         16       0          0
# 1   -152.4044          9       0          0
# 2   -123.1207        231       7          4
# 3   -122.6655         22       0          0
# 4   -122.0709         88       3          0
# ..        ...        ...     ...        ...
# 267  151.2093        307       5          4
# 268  153.4000        144       0          8
# 269  165.6180          2       0          0
# 270  174.8860         28       0          0
# 271  178.0650          1       0          0
#
# [272 rows x 4 columns]

# %%
data.plot(x='Country',y='Recovered') #plot between Country and recovered number
plt.xlabel('Country', fontsize=18)
plt.ylabel('Recovered', fontsize=16)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*3, Size[1]*1.5, forward=True)

# %%
plt.plot('Date', 'Deaths', data=data.groupby(['Date']).sum().reset_index(drop=None), color='red')
plt.plot('Date', 'Recovered', data=data.groupby(['Date']).sum().reset_index(drop=None), color='blue')
plt.xticks(rotation=60)
plt.ylabel('Number of cases',fontsize=10)
plt.xlabel('Dates',fontsize=10)
F = plt.gcf()
Size = F.get_size_inches()
F.set_size_inches(Size[0]*3, Size[1]*2, forward=True) 
plt.legend()
plt.show()
